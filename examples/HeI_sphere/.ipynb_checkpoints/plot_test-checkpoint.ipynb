# %%
fname = 't4tau1.fits.gz'

# %%
a = fits.open(fname)
#plt.plot(a[1].data['wavelength'], a[1].data['Jout'])
plt.plot(a[1].data['velocity'], a[1].data['Jout'])
plt.plot(a[1].data['velocity'], a[1].data['Jin'])
